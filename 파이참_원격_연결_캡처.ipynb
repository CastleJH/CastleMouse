# %% [markdown]
# <a href="https://colab.research.google.com/github/CastleJH/CastleMouse/blob/master/%ED%8C%8C%EC%9D%B4%EC%B0%B8_%EC%9B%90%EA%B2%A9_%EC%97%B0%EA%B2%B0_%EC%BA%A1%EC%B2%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/images/capture/"
# Out:
# Mounted at /content/gdrive

# %%
from PIL import Image

# %%
Image.open(root_dir + '1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1524x1081 at 0x7FF17D206F28>

# %% [markdown]
# Conda 환경으로 프로젝트를 생성한다.

# %%
Image.open(root_dir + '2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1560x592 at 0x7FF17C1248D0>

# %% [markdown]
# Ngrok로 Colab의 VM server에 접근할 것이다.

# %%
Image.open(root_dir + '3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1062 at 0x7FF17C124978>

# %% [markdown]
# Test Connection을 한 결과 성공적으로 연결된다.

# %%
Image.open(root_dir + '4.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1060 at 0x7FF17C124A20>

# %% [markdown]
# Root path란 colab의 root 디렉토리이다. Autodetect로 설정하였다. 그리고 advanced setting을 3600초로 하여 다른 일을 하는 동안에도 연결이 오래 유지되게 한다.

# %%
Image.open(root_dir + '5.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1060 at 0x7FF17C124B00>

# %% [markdown]
# Mapping한다. Deployment path는 프로젝트의 원격에서의 root 폴더이며, 위의 root path에 대한 상대 경로를 쓴다.

# %%
Image.open(root_dir + '6.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1060 at 0x7FF17C124C18>

# %% [markdown]
# 프로젝트의 interpreter를 원격의 usr/bin/python3.6으로 한다. Bin에서 로딩하는데 시간이 오래 걸렸다.

# %%
Image.open(root_dir + '7.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1060 at 0x7FF17C124D30>

# %% [markdown]
# Remote의 내부는 다음과 같이 생겼으며 익숙한 content/가 보인다.

# %%
Image.open(root_dir + '8.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1062 at 0x7FF17C124EF0>

# %% [markdown]
# 주피터 노트북 파일을 생성하고 configured server에 주소를 입력하여 다음과 같이 실행시킨다. 정상적으로 hello가 출력된다.

# %%
Image.open(root_dir + '9.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1062 at 0x7FF17C124F98>

# %% [markdown]
# 예시로 또다른 명령을 실행하니 잘 출력된다.
# Remote host를 보면 test.ipynb가 있는 것을 볼 수 있다. 파일을 수정하고 저장하면 파이참이 자동으로 변경된 것을 remote에 적용한다. 자유롭게 드래그하면서 다운로드/업로드 할 수도 있다.
